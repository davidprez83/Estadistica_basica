# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import math

# %% [markdown]
# # **Problem Set 1: Técnicas de conteo y teoría de probabilidades**
#
# **Asignatura:** Problemas de Astroestadística
# **Profesor:** Daniel Arbeláez Cardona
# **Institución:** Astronomía - Universidad de Antioquia

# %% [markdown]
# # **Punto 1**
#
# **Estrellas**
#
# Suponga que las estrellas en un cúmulo estelar se pueden clasificar según 2 características: color (rojas y azules) y tamaño (gigantes y "enanas"). Un experimento consiste en observar una estrella de dicho cúmulo de forma aleatoria, considerando que el 80% de las estrellas son rojas, el 70% de las estrellas rojas son enanas y el 90% de las estrellas azules son gigantes.
#
# Sea $A$ el suceso {se observa una estrella roja} y $B$ el suceso {se observa una estrella gigante}.
#
# Describir los siguientes sucesos y calcular su probabilidad:

# %% [markdown]
# **i)** $A \cup B$
#
#
# solucion:
#
# <center>
# <img src="Imagenes\Captura de pantalla 2026-07-02 191601.png" width="500">
# <p><b>Figura 1.</b> Esquema de la geometría del problema.</p>
# </center>

# %% [markdown]
# **ii)** $A \cap B$

# %% [markdown]
# **iii)** $A \cup B'$

# %% [markdown]
# **iv)** $A' \cup B'$

# %% [markdown]
# **v)** $A - B$

# %% [markdown]
# **vi)** $A' - B'$

# %% [markdown]
# **vii)** $(A \cap B) \cup (A \cap B')$

# %% [markdown]
# # **Punto 2**
#
# **Galaxias espirales**
#
# En la clasificación de Hubble encontramos las galaxias espirales divididas en dos tipos: barradas (SB) y no barradas (S). Además, se hace una clasificación según la disposición de sus brazos espirales y el tamaño del bulbo, que originalmente va desde la letra a hasta la c (ejemplos: SBa, Sb).
#
# Suponga que en un estudio hipotético se encontraron los siguientes porcentajes para cada tipo de galaxia espiral:
#
# | Tipo | a | b | c |
# | :---: | :---: | :---: | :---: |
# | **S** | 14% | 20% | 26% |
# | **SB** | 20% | 10% | 10% |
#
# Considere una galaxia espiral elegida aleatoriamente:

# %% [markdown]
# **a)** ¿Cuál es la probabilidad de que la galaxia elegida sea tipo a? ¿De que sea barrada?

# %% [markdown]
# **b)** Si se encuentra que la galaxia elegida es tipo a ¿Cuál es la probabilidad ahora de que la galaxia sea barrada? ¿Cómo interpreta esta probabilidad?

# %% [markdown]
# **c)** Si se encuentra que la galaxia elegida es barrada ¿Cuál es la probabilidad de que sea tipo a? ¿Cómo se compara ésta con la probabilidad encontrada en el literal (a)?

# %% [markdown]
# # **Punto 3**
#
# **Sistemas binarios**
#
# La mayoría de las estrellas que vemos en el cielo son sistemas binarios, con dos (o a veces más) estrellas orbitando un centro de masa común. Tal vez el 85% de las estrellas son sistemas binarios. Además, se estima que el 50-60% de las estrellas binarias son capaces de soportar planetas tipo terrestres habitables dentro de los rangos orbitales estables.
#
# Suponga que el universo es homogéneo e isotrópico.

# %% [markdown]
# **a)** ¿Cuál es la probabilidad de que, al mirar 10 estrellas en una noche de forma aleatoria, todas sean sistemas binarios?

# %% [markdown]
# **b)** ¿Cuál es la probabilidad de que, al mirar una estrella de forma aleatoria, se esté mirando un sistema binario capaz de soportar planetas tipo terrestres habitables?

# %% [markdown]
# # **Punto 4**
#
# **La bolita roja**
#
# La caja I contiene 3 bolas rojas y 7 azules, la caja II contiene 8 bolas rojas y 2 azules, y la caja III contiene 4 bolas rojas y 6 azules. Se requiere sacar la bola roja para ganarse un regalito.

# %% [markdown]
# **a)** ¿Con cuál caja se tiene mayor probabilidad de ganar?

# %% [markdown]
# **b)** Usted no conoce el contenido de cada caja, así que debe elegir una al azar. ¿Qué probabilidad tiene de ganar?

# %% [markdown]
# **c)** Suponga que usted es un feliz ganador ¿cuál es la probabilidad de haber sacado la bolita de la caja III? ¿Y de la caja II?

# %% [markdown]
# # **Punto 5**
#
# **Combinaciones con repetición**
#
# Una combinación con repetición de orden $r$ de los $n$ elementos de $A$ es una selección no ordenada de $r$ elementos de $A$ que pueden repetirse. El número de tales combinaciones se denota $CR_{n,r}$ y está dado por:
#
# $$CR_{n,r}=\binom{n+r-1}{r}$$

# %% [markdown]
# **a)** Demuestre la expresión anterior (Ayuda: Consulte sobre el método de barras y estrellas)

# %% [markdown]
# **b)** De cuántas formas se pueden elegir 15 estrellas entre 7 tipos espectrales si:
# - Se pueden elegir de cualquier forma.
# - Se debe elegir una de cada tipo.

# %% [markdown]
# # **Punto 6**
#
# **Manos de Póker**
#
# Se extraen 5 cartas de un mazo de 52 cartas. Hallar la probabilidad de extraer:

# %% [markdown]
# **a)** 4 ases y un rey

# %% [markdown]
# **b)** 3 dieces y 2 jotas

# %% [markdown]
# **c)** Un 9, 10, jota, reina y rey en cualquier orden (escalera a rey)

# %% [markdown]
# **d)** 3 de un palo y 2 de otro

# %% [markdown]
# **e)** Un trío y un par (full house)

# %% [markdown]
# **f)** Al menos un as

# %% [markdown]
# # **Punto 7**
#
# **Galaxias I**
#
# De 5 galaxias elípticas y 7 espirales se deben escoger 2 elípticas y 3 espirales para ser estudiadas dado que el tiempo de telescopio es limitado.
#
# ¿De cuántas formas se puede escoger entre las galaxias si:

# %% [markdown]
# **a)** Cualquiera de ellas puede ser escogida.

# %% [markdown]
# **b)** Una galaxia espiral en particular debe estar en el grupo a estudiar.

# %% [markdown]
# **c)** Dos galaxias elípticas en particular deben estar en el grupo a estudiar.

# %% [markdown]
# # **Punto 8**
#
# **Galaxias II**
#
# ¿De cuántas formas se pueden observar 7 galaxias en una noche, si:

# %% [markdown]
# **a)** Pueden observarse en cualquier orden.

# %% [markdown]
# **b)** Si dos galaxias determinadas no deben observarse una inmediatamente después de la otra.

# %% [markdown]
# # **Punto 9**
#
# **Observación de cúmulos**
#
# En una noche de observación particular, un conjunto de 30 cúmulos estelares cumplen con las condiciones óptimas para ser observados. De este conjunto tenemos que 8 son cúmulos jóvenes masivos, 10 son cúmulos globulares y 12 son cúmulos abiertos.

# %% [markdown]
# **a)** Se quieren observar tres cúmulos jóvenes masivos ¿De cuántas formas puede hacerse si el orden de observación importa?

# %% [markdown]
# **b)** Si se elijen 6 cúmulos de forma aleatoria:
# - ¿Cuántas formas posibles hay de hacer esto?
# - ¿Cuántas formas posibles hay de observar 2 cúmulos de cada tipo?
# - ¿Cuál es la probabilidad de observar 2 cúmulos de cada tipo?
# - ¿Cuál es la probabilidad de que todos sean del mismo tipo?

# %% [markdown]
# # **Punto 10**
#
# **Lanzamiento de dados**
#
# Elabore un código que lance dos dados regulares una cantidad $N$ de veces y que realice un histograma que cuente el número de veces que sale cada una de las posibles sumas.
#
# Utilice diferentes valores de $N$ y analice a partir de qué valor se podría decir que los resultados del experimento "se ajustan" al resultado esperado.
