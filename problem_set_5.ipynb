# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math as mt
import plotly.express as px
import plotly.graph_objects as go
from scipy.integrate import quad, dblquad
import sympy as sp
import nbformat

# %% [markdown]
# # **Punto 1**
#
# **Lanzamiento de moneda**
#
# Hallar la probabilidad de obtener entre 40 y 60 caras inclusive en 100 lanzamientos de una moneda. Compare los resultados entre una aproximación y el valor real.
#
# Para ensayar la hipótesis de que una moneda está bien hecha, se toma la siguiente regla de decisión:
#
# Se acepta la hipótesis si el número de caras en una serie de 100 lanzamientos se encuentra entre 40 y 60, ambos inclusive; de otro modo, se rechaza.

# %%
# Parametros de esta distribucion en específico


n = 100
p = 0.5
k_1 = 40
k_2 = 60

# definimos la función de densidad de probabilidad binomial
def binomial_pmf(k, n, p):
    return (mt.factorial(n) / (mt.factorial(k) * mt.factorial(n - k))) * (p ** k) * ((1 - p) ** (n - k))

# %%
# grafica de la función de densidad de probabilidad binomial
k_values = np.arange(0, n + 1)
binomial_values = [binomial_pmf(k, n, p) for k in k_values]

plt.figure(figsize=(8, 6))
plt.bar(k_values, binomial_values, color='skyblue')
plt.title('Función de Densidad de Probabilidad Binomial')
plt.xlabel('Número de éxitos (k)')
plt.ylabel('P(X = k)')
plt.xlim(0, n)
plt.grid(axis='y')
plt.show()

# %%
P_interes = np.sum([binomial_pmf(k, n, p) for k in range(k_1, k_2)])
print(f"La probabilidad de obtener entre {k_1} y {k_2} éxitos es: {P_interes:.4f}")
# Out:
# La probabilidad de obtener entre 40 y 60 éxitos es: 0.9540

# %% [markdown]
# **a)** Hallar la probabilidad de rechazar la hipótesis, cuando en realidad es cierta.

# %% [markdown]
# **Sln:** Sabemos que al ser $np >> 100$ esto implíca que $X \sim N[x;\mu = np, \sigma^2 = np(1-p)]$. Asi, la normal estandar respectiva a $X$ (cantidad de exitos) es:
#
# $$
# Z = \frac{X - np}{\sqrt{np (1-p)}}
# $$

# %%
def normal_pdf(x, mu, sigma2):
    sigma = np.sqrt(sigma2)
    return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)

# %%
#grafica de la función de densidad de probabilidad normal respectiva a este problema

mu = n * p
sigma2 = n * p * (1 - p)

x_values = np.linspace(0, n, 1000)
normal_values = [normal_pdf(x, mu, sigma2) for x in x_values]

plt.figure(figsize=(8, 6))
plt.plot(x_values, normal_values, color='orange')
plt.title('Función de Densidad de Probabilidad Normal Aproximada')
plt.xlabel('Número de éxitos (k)')
plt.ylabel('f(k)')
plt.xlim(0, n)
plt.grid()
plt.show()

# %% [markdown]
# En este problema tomamos como hipotesis nula $H_0: \text{ la moneda esta bien hecha}$ si se rechaza esta hipotesis aceptamos como cierta la hipotesis $H_a: \text{ la moneda no esta bien hecha}$ esto pasa si en 100 lanzamientos se dan menos de 40 o mas de 60 caras ($X$), esto es:
#
# $$
# P(X \leq 40) + P( X \geq 60) = \alpha
# $$

# %%
# Calculo de la probabilidad usando la aproximación normal

P_les_40 = quad(lambda x: normal_pdf(x, mu, sigma2), -np.inf, k_1)[0]
P_gre_60 = 1 - quad(lambda x: normal_pdf(x, mu, sigma2), -np.inf, k_2)[0]

P_interes_normal = P_les_40 + P_gre_60
print(f"La probabilidad de obtener de decir que la moneda esta sesgada y en realidad no lo este es del {P_interes_normal*100:.4f} %")
# Out:
# La probabilidad de obtener de decir que la moneda esta sesgada y en realidad no lo este es del 4.5500 %

# %%
2* 0.00179
# Out:
# 0.00358

# %% [markdown]
# **b)** Interpretar gráficamente la regla de decisión y el resultado del apartado (a).

# %%
# Llenar solo entre x=2 y x=8
plt.figure(figsize=(10, 6))
plt.plot(x_values, normal_values , 'b-', linewidth=2)

# Llenar entre dos valores de x
mask1 = (x_values <= 40)
mask2 = (x_values >= 60)
plt.fill_between(x_values[mask1], np.array(normal_values)[mask1], alpha=0.5, color='red', label='Área entre x=40 y x=60')
plt.fill_between(x_values[mask2], np.array(normal_values)[mask2], alpha=0.5, color='red', label='Área entre x=40 y x=60')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# El área roja representa la probabilidad de que, al lanzar n veces la moneda, el número de caras sea mayor a 60 o menor a 40, y que esto ocurra por pura casualidad. Esto también representa la probabilidad de afirmar que la moneda está mal hecha cuando en realidad está bien hecha.

# %% [markdown]
# **c)** ¿Qué conclusiones se sacarían si en la muestra de 100 lanzamientos se obtuviesen 53 caras? ¿60 caras?

# %% [markdown]
# **respuesta:** La conclusión sería que basicamente se aprueba la hipotesis nula $H_0$

# %% [markdown]
# **d)** ¿Podrían ser erróneas las conclusiones de (c)? Explicar.

# %% [markdown]
# **Respuesta.** Si, podrian ser erroneas debido a que estamos asumiendo que para que una moneda este bien hecha, al lanzarla 100 veces, las veces que caiga una cara debe de ser un valor entre 40 y 50. Para esto tenemos que calcular la probabilidad de cometer un error de tipo 2. Es decir, la probabilidad de no negar $H_0$ y que $H_0$ sea falso.

# %% [markdown]
# **e)** ¿Cuál es la probabilidad de aceptar la hipótesis de que la moneda está bien hecha cuando la probabilidad real de cara es p = 0.7?

# %%
# si p = 0.7 en realidad la moneda esta sesgada, entonces la probabilidad de obtener entre 40 y 60 éxitos es:

p_sesgada = 0.7
mu_sesgada = n * p_sesgada
sigma2_sesgada = n * p_sesgada * (1 - p_sesgada)

P_interes_sesgada = quad(lambda x: normal_pdf(x, mu_sesgada, np.sqrt(sigma2_sesgada)), k_1, k_2)[0]

print(f"La probabilidad de obtener entre {k_1} y {k_2} éxitos con una moneda sesgada (p=0.7) es: {P_interes_sesgada}")
# Out:
# La probabilidad de obtener entre 40 y 60 éxitos con una moneda sesgada (p=0.7) es: 1.4959159506592716e-06

# %% [markdown]
# **Respuesta.** Basicamente nula la probabilidad.

# %%
# Superposición de las normales para p=0.5 y p=0.7
p1 = 0.5
p2 = 0.7

mu1 = n * p1
sigma2_1 = n * p1 * (1 - p1)

mu2 = n * p2
sigma2_2 = n * p2 * (1 - p2)

x_values = np.linspace(0, n, 1000)
normal_1 = [normal_pdf(x, mu1, sigma2_1) for x in x_values]
normal_2 = [normal_pdf(x, mu2, sigma2_2) for x in x_values]

plt.figure(figsize=(10, 6))
plt.plot(x_values, normal_1, label='Normal con p = 0.5', color='blue', linewidth=2)
plt.plot(x_values, normal_2, label='Normal con p = 0.7', color='orange', linewidth=2, linestyle='--')

# Sombrear el área de error tipo II: aceptar H0 cuando en realidad p = 0.7
mask = (x_values >= 40) & (x_values <= 60)
plt.fill_between(
    x_values[mask],
    np.array(normal_2)[mask],
    color='red',
    alpha=0.5,
    label='Error tipo II: 40 ≤ X ≤ 60 bajo p = 0.7'
)

plt.axvline(40, color='gray', linestyle='--', linewidth=1)
plt.axvline(60, color='gray', linestyle='--', linewidth=1)

plt.title('Distribuciones normales superpuestas y error tipo II')
plt.xlabel('Número de caras (X)')
plt.ylabel('Densidad')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Punto 2**
#
# **Elecciones.**
#
# Dos partidos políticos, $G$ y $U$, han comenzado su campaña electoral en el país. Sea $p$ la proporción de todos los votantes potenciales que favorecen a $U$ sobre $G$. Considere probar $H0: p = 0.5$ contra $Ha: p \neq 0.5$, basado en una muestra aleatoria de 100 individuos. Sea el estadístico de prueba $X$ el número de la muestra que favorece a $U$, y $x$ el valor observado de $X$.

# %% [markdown]
# **a)**
# Describa los errores tipo I y tipo II en este contexto.

# %% [markdown]
# ### **b)**
# Suponga que $x = 37$. ¿Qué valores de $X$ son igual o más contradictorios que éste con $H_0$?

# %% [markdown]
# ### **c)**
# ¿Cuál es la distribución de probabilidades del estadístico de prueba $X$ cuando $H_0$ es cierto? Use esto para calcular la probabilidad de obtener un valor igual o más contradictorio a $H_0$ cuando éste es cierto (P-value) si $x = 37$.

# %% [markdown]
# ### **d)**
# Si se va a rechazar $H_0$ cuando P-value $\leq 0.056$, calcule la probabilidad de tener un error de tipo II cuando $p$ tiene valores de 0.4, 0.3, 0.6 y 0.7. [Ayuda: ¿A qué desigualdades que involucran a $x$ es equivalente P-value $> 0.056$]

# %% [markdown]
# ### **e)**
# Usando el procedimiento de prueba de (d), ¿qué concluiría si 37 de los 100 consultados favorecieran a U?

# %% [markdown]
# ## **Punto 3**
#
# **Consumo de alcohol**
#
# Un estudio (hipotético) en la Universidad encontró que 51 estudiantes en una muestra de 462 se abstienen de consumir alcohol. ¿Estos resultados proporcionan suficiente evidencia para concluir que más del 10% de la población se abstiene de consumir alcohol? Realice la prueba de hipótesis apropiada.

# %%
# definamos los parametros obtenidos del muestreo

x = 51
n = 462
p_muestral = x / n

p_Hnula = 0.1     # hipotesis nula

# %% [markdown]
# Nuestra hipotesis nula será $H_0 : p = 0.1$ y $H_a: p > 0.1$. aceptando como cierta la hipotesis nula vemos que el estimador $\hat{p}$ sigue una distribucion normal de la forma:
#
# $\hat{P} \sim N(\hat{p}, \mu = p_0, \sigma^2 = \frac{p(1-p)}{n})$

# %%
# parametros de la normal que sigue el estimador p_hat

mu_p_hat = p_Hnula
sigma2_p_hat = (p_Hnula * (1 - p_Hnula)) / n

normal_p_hat = lambda x: normal_pdf(x, mu_p_hat, sigma2_p_hat)

# %%
#grafica de la función de densidad de probabilidad normal respectiva a este problema
x_values_p_hat = np.linspace(0, 2*0.1, 1000)
normal_values_p_hat = [normal_p_hat(x) for x in x_values_p_hat]

plt.figure(figsize=(8, 6))
plt.plot(x_values_p_hat, normal_values_p_hat)
plt.title('Función de Densidad de Probabilidad Normal para p_hat')
plt.xlabel('p_hat')
plt.ylabel('f(p_hat)')
plt.grid()
plt.show()

# %% [markdown]
# Se tomará un nivel de significancia para esta prueba de hipotesis de $\alpha = 0.05$

# %% [markdown]
# Se deben de buscar un valor critico ($\hat{p}_c$) tal que $P(\hat{p}> \hat{p}_c) = 0.95$

# %%
condicion = 0.95 
xs = np.linspace(0, 0.2, 1000)

for i, x in enumerate(xs):
    area = quad(normal_p_hat, 0, x)[0]
    print(f"Área bajo la curva desde 0 hasta {x:.4f}: {area:.4f}")
    if (abs((area - condicion)/condicion) < 1e-3):
        x_critico = x
        break
# Out:
# Área bajo la curva desde 0 hasta 0.0000: 0.0000
# Área bajo la curva desde 0 hasta 0.0002: 0.0000
# Área bajo la curva desde 0 hasta 0.0004: 0.0000
# Área bajo la curva desde 0 hasta 0.0006: 0.0000
# Área bajo la curva desde 0 hasta 0.0008: 0.0000
# Área bajo la curva desde 0 hasta 0.0010: 0.0000
# Área bajo la curva desde 0 hasta 0.0012: 0.0000
# Área bajo la curva desde 0 hasta 0.0014: 0.0000
# Área bajo la curva desde 0 hasta 0.0016: 0.0000
# Área bajo la curva desde 0 hasta 0.0018: 0.0000
# Área bajo la curva desde 0 hasta 0.0020: 0.0000
# Área bajo la curva desde 0 hasta 0.0022: 0.0000
# Área bajo la curva desde 0 hasta 0.0024: 0.0000
# Área bajo la curva desde 0 hasta 0.0026: 0.0000
# Área bajo la curva desde 0 hasta 0.0028: 0.0000
# Área bajo la curva desde 0 hasta 0.0030: 0.0000
# Área bajo la curva desde 0 hasta 0.0032: 0.0000
# Área bajo la curva desde 0 hasta 0.0034: 0.0000
# Área bajo la curva desde 0 hasta 0.0036: 0.0000
# Área bajo la curva desde 0 hasta 0.0038: 0.0000
# Área bajo la curva desde 0 hasta 0.0040: 0.0000
# Área bajo la curva desde 0 hasta 0.0042: 0.0000
# Área bajo la curva desde 0 hasta 0.0044: 0.0000
# Área bajo la curva desde 0 hasta 0.0046: 0.0000
# Área bajo la curva desde 0 hasta 0.0048: 0.0000
# Área bajo la curva desde 0 hasta 0.0050: 0.0000
# Área bajo la curva desde 0 hasta 0.0052: 0.0000
# Área bajo la curva desde 0 hasta 0.0054: 0.0000
# Área bajo la curva desde 0 hasta 0.0056: 0.0000
# Área bajo la curva desde 0 hasta 0.0058: 0.0000
# Área bajo la curva desde 0 hasta 0.0060: 0.0000
# Área bajo la curva desde 0 hasta 0.0062: 0.0000
# Área bajo la curva desde 0 hasta 0.0064: 0.0000
# Área bajo la curva desde 0 hasta 0.0066: 0.0000
# Área bajo la curva desde 0 hasta 0.0068: 0.0000
# Área bajo la curva desde 0 hasta 0.0070: 0.0000
# Área bajo la curva desde 0 hasta 0.0072: 0.0000
# Área bajo la curva desde 0 hasta 0.0074: 0.0000
# Área bajo la curva desde 0 hasta 0.0076: 0.0000
# Área bajo la curva desde 0 hasta 0.0078: 0.0000
# Área bajo la curva desde 0 hasta 0.0080: 0.0000
# Área bajo la curva desde 0 hasta 0.0082: 0.0000
# Área bajo la curva desde 0 hasta 0.0084: 0.0000
# Área bajo la curva desde 0 hasta 0.0086: 0.0000
# Área bajo la curva desde 0 hasta 0.0088: 0.0000
# Área bajo la curva desde 0 hasta 0.0090: 0.0000
# Área bajo la curva desde 0 hasta 0.0092: 0.0000
# Área bajo la curva desde 0 hasta 0.0094: 0.0000
# Área bajo la curva desde 0 hasta 0.0096: 0.0000
# Área bajo la curva desde 0 hasta 0.0098: 0.0000
# Área bajo la curva desde 0 hasta 0.0100: 0.0000
# Área bajo la curva desde 0 hasta 0.0102: 0.0000
# Área bajo la curva desde 0 hasta 0.0104: 0.0000
# Área bajo la curva desde 0 hasta 0.0106: 0.0000
# Área bajo la curva desde 0 hasta 0.0108: 0.0000
# Área bajo la curva desde 0 hasta 0.0110: 0.0000
# Área bajo la curva desde 0 hasta 0.0112: 0.0000
# Área bajo la curva desde 0 hasta 0.0114: 0.0000
# Área bajo la curva desde 0 hasta 0.0116: 0.0000
# Área bajo la curva desde 0 hasta 0.0118: 0.0000
# Área bajo la curva desde 0 hasta 0.0120: 0.0000
# Área bajo la curva desde 0 hasta 0.0122: 0.0000
# Área bajo la curva desde 0 hasta 0.0124: 0.0000
# Área bajo la curva desde 0 hasta 0.0126: 0.0000
# Área bajo la curva desde 0 hasta 0.0128: 0.0000
# Área bajo la curva desde 0 hasta 0.0130: 0.0000
# Área bajo la curva desde 0 hasta 0.0132: 0.0000
# Área bajo la curva desde 0 hasta 0.0134: 0.0000
# Área bajo la curva desde 0 hasta 0.0136: 0.0000
# Área bajo la curva desde 0 hasta 0.0138: 0.0000
# Área bajo la curva desde 0 hasta 0.0140: 0.0000
# Área bajo la curva desde 0 hasta 0.0142: 0.0000
# Área bajo la curva desde 0 hasta 0.0144: 0.0000
# Área bajo la curva desde 0 hasta 0.0146: 0.0000
# Área bajo la curva desde 0 hasta 0.0148: 0.0000
# Área bajo la curva desde 0 hasta 0.0150: 0.0000
# Área bajo la curva desde 0 hasta 0.0152: 0.0000
# Área bajo la curva desde 0 hasta 0.0154: 0.0000
# Área bajo la curva desde 0 hasta 0.0156: 0.0000
# Área bajo la curva desde 0 hasta 0.0158: 0.0000
# Área bajo la curva desde 0 hasta 0.0160: 0.0000
# Área bajo la curva desde 0 hasta 0.0162: 0.0000
# Área bajo la curva desde 0 hasta 0.0164: 0.0000
# Área bajo la curva desde 0 hasta 0.0166: 0.0000
# Área bajo la curva desde 0 hasta 0.0168: 0.0000
# Área bajo la curva desde 0 hasta 0.0170: 0.0000
# Área bajo la curva desde 0 hasta 0.0172: 0.0000
# Área bajo la curva desde 0 hasta 0.0174: 0.0000
# Área bajo la curva desde 0 hasta 0.0176: 0.0000
# Área bajo la curva desde 0 hasta 0.0178: 0.0000
# Área bajo la curva desde 0 hasta 0.0180: 0.0000
# Área bajo la curva desde 0 hasta 0.0182: 0.0000
# Área bajo la curva desde 0 hasta 0.0184: 0.0000
# Área bajo la curva desde 0 hasta 0.0186: 0.0000
# Área bajo la curva desde 0 hasta 0.0188: 0.0000
# Área bajo la curva desde 0 hasta 0.0190: 0.0000
# Área bajo la curva desde 0 hasta 0.0192: 0.0000
# Área bajo la curva desde 0 hasta 0.0194: 0.0000
# Área bajo la curva desde 0 hasta 0.0196: 0.0000
# Área bajo la curva desde 0 hasta 0.0198: 0.0000
# Área bajo la curva desde 0 hasta 0.0200: 0.0000
# Área bajo la curva desde 0 hasta 0.0202: 0.0000
# Área bajo la curva desde 0 hasta 0.0204: 0.0000
# Área bajo la curva desde 0 hasta 0.0206: 0.0000
# Área bajo la curva desde 0 hasta 0.0208: 0.0000
# Área bajo la curva desde 0 hasta 0.0210: 0.0000
# Área bajo la curva desde 0 hasta 0.0212: 0.0000
# Área bajo la curva desde 0 hasta 0.0214: 0.0000
# Área bajo la curva desde 0 hasta 0.0216: 0.0000
# Área bajo la curva desde 0 hasta 0.0218: 0.0000
# Área bajo la curva desde 0 hasta 0.0220: 0.0000
# Área bajo la curva desde 0 hasta 0.0222: 0.0000
# Área bajo la curva desde 0 hasta 0.0224: 0.0000
# Área bajo la curva desde 0 hasta 0.0226: 0.0000
# Área bajo la curva desde 0 hasta 0.0228: 0.0000
# Área bajo la curva desde 0 hasta 0.0230: 0.0000
# Área bajo la curva desde 0 hasta 0.0232: 0.0000
# Área bajo la curva desde 0 hasta 0.0234: 0.0000
# Área bajo la curva desde 0 hasta 0.0236: 0.0000
# Área bajo la curva desde 0 hasta 0.0238: 0.0000
# Área bajo la curva desde 0 hasta 0.0240: 0.0000
# Área bajo la curva desde 0 hasta 0.0242: 0.0000
# Área bajo la curva desde 0 hasta 0.0244: 0.0000
# Área bajo la curva desde 0 hasta 0.0246: 0.0000
# Área bajo la curva desde 0 hasta 0.0248: 0.0000
# Área bajo la curva desde 0 hasta 0.0250: 0.0000
# Área bajo la curva desde 0 hasta 0.0252: 0.0000
# Área bajo la curva desde 0 hasta 0.0254: 0.0000
# Área bajo la curva desde 0 hasta 0.0256: 0.0000
# Área bajo la curva desde 0 hasta 0.0258: 0.0000
# Área bajo la curva desde 0 hasta 0.0260: 0.0000
# Área bajo la curva desde 0 hasta 0.0262: 0.0000
# Área bajo la curva desde 0 hasta 0.0264: 0.0000
# Área bajo la curva desde 0 hasta 0.0266: 0.0000
# Área bajo la curva desde 0 hasta 0.0268: 0.0000
# Área bajo la curva desde 0 hasta 0.0270: 0.0000
# Área bajo la curva desde 0 hasta 0.0272: 0.0000
# Área bajo la curva desde 0 hasta 0.0274: 0.0000
# Área bajo la curva desde 0 hasta 0.0276: 0.0000
# Área bajo la curva desde 0 hasta 0.0278: 0.0000
# Área bajo la curva desde 0 hasta 0.0280: 0.0000
# Área bajo la curva desde 0 hasta 0.0282: 0.0000
# Área bajo la curva desde 0 hasta 0.0284: 0.0000
# Área bajo la curva desde 0 hasta 0.0286: 0.0000
# Área bajo la curva desde 0 hasta 0.0288: 0.0000
# Área bajo la curva desde 0 hasta 0.0290: 0.0000
# Área bajo la curva desde 0 hasta 0.0292: 0.0000
# Área bajo la curva desde 0 hasta 0.0294: 0.0000
# Área bajo la curva desde 0 hasta 0.0296: 0.0000
# Área bajo la curva desde 0 hasta 0.0298: 0.0000
# Área bajo la curva desde 0 hasta 0.0300: 0.0000
# Área bajo la curva desde 0 hasta 0.0302: 0.0000
# Área bajo la curva desde 0 hasta 0.0304: 0.0000
# Área bajo la curva desde 0 hasta 0.0306: 0.0000
# Área bajo la curva desde 0 hasta 0.0308: 0.0000
# Área bajo la curva desde 0 hasta 0.0310: 0.0000
# Área bajo la curva desde 0 hasta 0.0312: 0.0000
# Área bajo la curva desde 0 hasta 0.0314: 0.0000
# Área bajo la curva desde 0 hasta 0.0316: 0.0000
# Área bajo la curva desde 0 hasta 0.0318: 0.0000
# Área bajo la curva desde 0 hasta 0.0320: 0.0000
# Área bajo la curva desde 0 hasta 0.0322: 0.0000
# Área bajo la curva desde 0 hasta 0.0324: 0.0000
# Área bajo la curva desde 0 hasta 0.0326: 0.0000
# Área bajo la curva desde 0 hasta 0.0328: 0.0000
# Área bajo la curva desde 0 hasta 0.0330: 0.0000
# Área bajo la curva desde 0 hasta 0.0332: 0.0000
# Área bajo la curva desde 0 hasta 0.0334: 0.0000
# Área bajo la curva desde 0 hasta 0.0336: 0.0000
# Área bajo la curva desde 0 hasta 0.0338: 0.0000
# Área bajo la curva desde 0 hasta 0.0340: 0.0000
# Área bajo la curva desde 0 hasta 0.0342: 0.0000
# Área bajo la curva desde 0 hasta 0.0344: 0.0000
# Área bajo la curva desde 0 hasta 0.0346: 0.0000
# Área bajo la curva desde 0 hasta 0.0348: 0.0000
# Área bajo la curva desde 0 hasta 0.0350: 0.0000
# Área bajo la curva desde 0 hasta 0.0352: 0.0000
# Área bajo la curva desde 0 hasta 0.0354: 0.0000
# Área bajo la curva desde 0 hasta 0.0356: 0.0000
# Área bajo la curva desde 0 hasta 0.0358: 0.0000
# Área bajo la curva desde 0 hasta 0.0360: 0.0000
# Área bajo la curva desde 0 hasta 0.0362: 0.0000
# Área bajo la curva desde 0 hasta 0.0364: 0.0000
# Área bajo la curva desde 0 hasta 0.0366: 0.0000
# Área bajo la curva desde 0 hasta 0.0368: 0.0000
# Área bajo la curva desde 0 hasta 0.0370: 0.0000
# Área bajo la curva desde 0 hasta 0.0372: 0.0000
# Área bajo la curva desde 0 hasta 0.0374: 0.0000
# Área bajo la curva desde 0 hasta 0.0376: 0.0000
# Área bajo la curva desde 0 hasta 0.0378: 0.0000
# Área bajo la curva desde 0 hasta 0.0380: 0.0000
# Área bajo la curva desde 0 hasta 0.0382: 0.0000
# Área bajo la curva desde 0 hasta 0.0384: 0.0000
# Área bajo la curva desde 0 hasta 0.0386: 0.0000
# Área bajo la curva desde 0 hasta 0.0388: 0.0000
# Área bajo la curva desde 0 hasta 0.0390: 0.0000
# Área bajo la curva desde 0 hasta 0.0392: 0.0000
# Área bajo la curva desde 0 hasta 0.0394: 0.0000
# Área bajo la curva desde 0 hasta 0.0396: 0.0000
# Área bajo la curva desde 0 hasta 0.0398: 0.0000
# Área bajo la curva desde 0 hasta 0.0400: 0.0000
# Área bajo la curva desde 0 hasta 0.0402: 0.0000
# Área bajo la curva desde 0 hasta 0.0404: 0.0000
# Área bajo la curva desde 0 hasta 0.0406: 0.0000
# Área bajo la curva desde 0 hasta 0.0408: 0.0000
# Área bajo la curva desde 0 hasta 0.0410: 0.0000
# Área bajo la curva desde 0 hasta 0.0412: 0.0000
# Área bajo la curva desde 0 hasta 0.0414: 0.0000
# Área bajo la curva desde 0 hasta 0.0416: 0.0000
# Área bajo la curva desde 0 hasta 0.0418: 0.0000
# Área bajo la curva desde 0 hasta 0.0420: 0.0000
# Área bajo la curva desde 0 hasta 0.0422: 0.0000
# Área bajo la curva desde 0 hasta 0.0424: 0.0000
# Área bajo la curva desde 0 hasta 0.0426: 0.0000
# Área bajo la curva desde 0 hasta 0.0428: 0.0000
# Área bajo la curva desde 0 hasta 0.0430: 0.0000
# Área bajo la curva desde 0 hasta 0.0432: 0.0000
# Área bajo la curva desde 0 hasta 0.0434: 0.0000
# Área bajo la curva desde 0 hasta 0.0436: 0.0000
# Área bajo la curva desde 0 hasta 0.0438: 0.0000
# Área bajo la curva desde 0 hasta 0.0440: 0.0000
# Área bajo la curva desde 0 hasta 0.0442: 0.0000
# Área bajo la curva desde 0 hasta 0.0444: 0.0000
# Área bajo la curva desde 0 hasta 0.0446: 0.0000
# Área bajo la curva desde 0 hasta 0.0448: 0.0000
# Área bajo la curva desde 0 hasta 0.0450: 0.0000
# Área bajo la curva desde 0 hasta 0.0452: 0.0000
# Área bajo la curva desde 0 hasta 0.0454: 0.0000
# Área bajo la curva desde 0 hasta 0.0456: 0.0000
# Área bajo la curva desde 0 hasta 0.0458: 0.0001
# Área bajo la curva desde 0 hasta 0.0460: 0.0001
# Área bajo la curva desde 0 hasta 0.0462: 0.0001
# Área bajo la curva desde 0 hasta 0.0464: 0.0001
# Área bajo la curva desde 0 hasta 0.0466: 0.0001
# Área bajo la curva desde 0 hasta 0.0468: 0.0001
# Área bajo la curva desde 0 hasta 0.0470: 0.0001
# Área bajo la curva desde 0 hasta 0.0472: 0.0001
# Área bajo la curva desde 0 hasta 0.0474: 0.0001
# Área bajo la curva desde 0 hasta 0.0476: 0.0001
# Área bajo la curva desde 0 hasta 0.0478: 0.0001
# Área bajo la curva desde 0 hasta 0.0480: 0.0001
# Área bajo la curva desde 0 hasta 0.0482: 0.0001
# Área bajo la curva desde 0 hasta 0.0484: 0.0001
# Área bajo la curva desde 0 hasta 0.0486: 0.0001
# Área bajo la curva desde 0 hasta 0.0488: 0.0001
# Área bajo la curva desde 0 hasta 0.0490: 0.0001
# Área bajo la curva desde 0 hasta 0.0492: 0.0001
# Área bajo la curva desde 0 hasta 0.0494: 0.0001
# Área bajo la curva desde 0 hasta 0.0496: 0.0002
# Área bajo la curva desde 0 hasta 0.0498: 0.0002
# Área bajo la curva desde 0 hasta 0.0501: 0.0002
# Área bajo la curva desde 0 hasta 0.0503: 0.0002
# Área bajo la curva desde 0 hasta 0.0505: 0.0002
# Área bajo la curva desde 0 hasta 0.0507: 0.0002
# Área bajo la curva desde 0 hasta 0.0509: 0.0002
# Área bajo la curva desde 0 hasta 0.0511: 0.0002
# Área bajo la curva desde 0 hasta 0.0513: 0.0002
# Área bajo la curva desde 0 hasta 0.0515: 0.0003
# Área bajo la curva desde 0 hasta 0.0517: 0.0003
# Área bajo la curva desde 0 hasta 0.0519: 0.0003
# Área bajo la curva desde 0 hasta 0.0521: 0.0003
# Área bajo la curva desde 0 hasta 0.0523: 0.0003
# Área bajo la curva desde 0 hasta 0.0525: 0.0003
# Área bajo la curva desde 0 hasta 0.0527: 0.0003
# Área bajo la curva desde 0 hasta 0.0529: 0.0004
# Área bajo la curva desde 0 hasta 0.0531: 0.0004
# Área bajo la curva desde 0 hasta 0.0533: 0.0004
# Área bajo la curva desde 0 hasta 0.0535: 0.0004
# Área bajo la curva desde 0 hasta 0.0537: 0.0004
# Área bajo la curva desde 0 hasta 0.0539: 0.0005
# Área bajo la curva desde 0 hasta 0.0541: 0.0005
# Área bajo la curva desde 0 hasta 0.0543: 0.0005
# Área bajo la curva desde 0 hasta 0.0545: 0.0006
# Área bajo la curva desde 0 hasta 0.0547: 0.0006
# Área bajo la curva desde 0 hasta 0.0549: 0.0006
# Área bajo la curva desde 0 hasta 0.0551: 0.0006
# Área bajo la curva desde 0 hasta 0.0553: 0.0007
# Área bajo la curva desde 0 hasta 0.0555: 0.0007
# Área bajo la curva desde 0 hasta 0.0557: 0.0007
# Área bajo la curva desde 0 hasta 0.0559: 0.0008
# Área bajo la curva desde 0 hasta 0.0561: 0.0008
# Área bajo la curva desde 0 hasta 0.0563: 0.0009
# Área bajo la curva desde 0 hasta 0.0565: 0.0009
# Área bajo la curva desde 0 hasta 0.0567: 0.0010
# Área bajo la curva desde 0 hasta 0.0569: 0.0010
# Área bajo la curva desde 0 hasta 0.0571: 0.0010
# Área bajo la curva desde 0 hasta 0.0573: 0.0011
# Área bajo la curva desde 0 hasta 0.0575: 0.0012
# Área bajo la curva desde 0 hasta 0.0577: 0.0012
# Área bajo la curva desde 0 hasta 0.0579: 0.0013
# Área bajo la curva desde 0 hasta 0.0581: 0.0013
# Área bajo la curva desde 0 hasta 0.0583: 0.0014
# Área bajo la curva desde 0 hasta 0.0585: 0.0015
# Área bajo la curva desde 0 hasta 0.0587: 0.0015
# Área bajo la curva desde 0 hasta 0.0589: 0.0016
# Área bajo la curva desde 0 hasta 0.0591: 0.0017
# Área bajo la curva desde 0 hasta 0.0593: 0.0018
# Área bajo la curva desde 0 hasta 0.0595: 0.0018
# Área bajo la curva desde 0 hasta 0.0597: 0.0019
# Área bajo la curva desde 0 hasta 0.0599: 0.0020
# Área bajo la curva desde 0 hasta 0.0601: 0.0021
# Área bajo la curva desde 0 hasta 0.0603: 0.0022
# Área bajo la curva desde 0 hasta 0.0605: 0.0023
# Área bajo la curva desde 0 hasta 0.0607: 0.0024
# Área bajo la curva desde 0 hasta 0.0609: 0.0025
# Área bajo la curva desde 0 hasta 0.0611: 0.0026
# Área bajo la curva desde 0 hasta 0.0613: 0.0028
# Área bajo la curva desde 0 hasta 0.0615: 0.0029
# Área bajo la curva desde 0 hasta 0.0617: 0.0030
# Área bajo la curva desde 0 hasta 0.0619: 0.0031
# Área bajo la curva desde 0 hasta 0.0621: 0.0033
# Área bajo la curva desde 0 hasta 0.0623: 0.0034
# Área bajo la curva desde 0 hasta 0.0625: 0.0036
# Área bajo la curva desde 0 hasta 0.0627: 0.0037
# Área bajo la curva desde 0 hasta 0.0629: 0.0039
# Área bajo la curva desde 0 hasta 0.0631: 0.0041
# Área bajo la curva desde 0 hasta 0.0633: 0.0042
# Área bajo la curva desde 0 hasta 0.0635: 0.0044
# Área bajo la curva desde 0 hasta 0.0637: 0.0046
# Área bajo la curva desde 0 hasta 0.0639: 0.0048
# Área bajo la curva desde 0 hasta 0.0641: 0.0050
# Área bajo la curva desde 0 hasta 0.0643: 0.0052
# Área bajo la curva desde 0 hasta 0.0645: 0.0054
# Área bajo la curva desde 0 hasta 0.0647: 0.0057
# Área bajo la curva desde 0 hasta 0.0649: 0.0059
# Área bajo la curva desde 0 hasta 0.0651: 0.0062
# Área bajo la curva desde 0 hasta 0.0653: 0.0064
# Área bajo la curva desde 0 hasta 0.0655: 0.0067
# Área bajo la curva desde 0 hasta 0.0657: 0.0069
# Área bajo la curva desde 0 hasta 0.0659: 0.0072
# Área bajo la curva desde 0 hasta 0.0661: 0.0075
# Área bajo la curva desde 0 hasta 0.0663: 0.0078
# Área bajo la curva desde 0 hasta 0.0665: 0.0081
# Área bajo la curva desde 0 hasta 0.0667: 0.0085
# Área bajo la curva desde 0 hasta 0.0669: 0.0088
# Área bajo la curva desde 0 hasta 0.0671: 0.0091
# Área bajo la curva desde 0 hasta 0.0673: 0.0095
# Área bajo la curva desde 0 hasta 0.0675: 0.0099
# Área bajo la curva desde 0 hasta 0.0677: 0.0103
# Área bajo la curva desde 0 hasta 0.0679: 0.0107
# Área bajo la curva desde 0 hasta 0.0681: 0.0111
# Área bajo la curva desde 0 hasta 0.0683: 0.0115
# Área bajo la curva desde 0 hasta 0.0685: 0.0119
# Área bajo la curva desde 0 hasta 0.0687: 0.0124
# Área bajo la curva desde 0 hasta 0.0689: 0.0129
# Área bajo la curva desde 0 hasta 0.0691: 0.0133
# Área bajo la curva desde 0 hasta 0.0693: 0.0138
# Área bajo la curva desde 0 hasta 0.0695: 0.0144
# Área bajo la curva desde 0 hasta 0.0697: 0.0149
# Área bajo la curva desde 0 hasta 0.0699: 0.0154
# Área bajo la curva desde 0 hasta 0.0701: 0.0160
# Área bajo la curva desde 0 hasta 0.0703: 0.0166
# Área bajo la curva desde 0 hasta 0.0705: 0.0172
# Área bajo la curva desde 0 hasta 0.0707: 0.0178
# Área bajo la curva desde 0 hasta 0.0709: 0.0184
# Área bajo la curva desde 0 hasta 0.0711: 0.0191
# Área bajo la curva desde 0 hasta 0.0713: 0.0198
# Área bajo la curva desde 0 hasta 0.0715: 0.0205
# Área bajo la curva desde 0 hasta 0.0717: 0.0212
# Área bajo la curva desde 0 hasta 0.0719: 0.0219
# Área bajo la curva desde 0 hasta 0.0721: 0.0227
# Área bajo la curva desde 0 hasta 0.0723: 0.0235
# Área bajo la curva desde 0 hasta 0.0725: 0.0243
# Área bajo la curva desde 0 hasta 0.0727: 0.0251
# Área bajo la curva desde 0 hasta 0.0729: 0.0260
# Área bajo la curva desde 0 hasta 0.0731: 0.0269
# Área bajo la curva desde 0 hasta 0.0733: 0.0278
# Área bajo la curva desde 0 hasta 0.0735: 0.0287
# Área bajo la curva desde 0 hasta 0.0737: 0.0296
# Área bajo la curva desde 0 hasta 0.0739: 0.0306
# Área bajo la curva desde 0 hasta 0.0741: 0.0316
# Área bajo la curva desde 0 hasta 0.0743: 0.0327
# Área bajo la curva desde 0 hasta 0.0745: 0.0337
# Área bajo la curva desde 0 hasta 0.0747: 0.0348
# Área bajo la curva desde 0 hasta 0.0749: 0.0359
# Área bajo la curva desde 0 hasta 0.0751: 0.0371
# Área bajo la curva desde 0 hasta 0.0753: 0.0382
# Área bajo la curva desde 0 hasta 0.0755: 0.0394
# Área bajo la curva desde 0 hasta 0.0757: 0.0407
# Área bajo la curva desde 0 hasta 0.0759: 0.0420
# Área bajo la curva desde 0 hasta 0.0761: 0.0433
# Área bajo la curva desde 0 hasta 0.0763: 0.0446
# Área bajo la curva desde 0 hasta 0.0765: 0.0460
# Área bajo la curva desde 0 hasta 0.0767: 0.0474
# Área bajo la curva desde 0 hasta 0.0769: 0.0488
# Área bajo la curva desde 0 hasta 0.0771: 0.0503
# Área bajo la curva desde 0 hasta 0.0773: 0.0518
# Área bajo la curva desde 0 hasta 0.0775: 0.0533
# Área bajo la curva desde 0 hasta 0.0777: 0.0549
# Área bajo la curva desde 0 hasta 0.0779: 0.0565
# Área bajo la curva desde 0 hasta 0.0781: 0.0581
# Área bajo la curva desde 0 hasta 0.0783: 0.0598
# Área bajo la curva desde 0 hasta 0.0785: 0.0615
# Área bajo la curva desde 0 hasta 0.0787: 0.0633
# Área bajo la curva desde 0 hasta 0.0789: 0.0651
# Área bajo la curva desde 0 hasta 0.0791: 0.0669
# Área bajo la curva desde 0 hasta 0.0793: 0.0688
# Área bajo la curva desde 0 hasta 0.0795: 0.0707
# Área bajo la curva desde 0 hasta 0.0797: 0.0727
# Área bajo la curva desde 0 hasta 0.0799: 0.0747
# Área bajo la curva desde 0 hasta 0.0801: 0.0768
# Área bajo la curva desde 0 hasta 0.0803: 0.0788
# Área bajo la curva desde 0 hasta 0.0805: 0.0810
# Área bajo la curva desde 0 hasta 0.0807: 0.0832
# Área bajo la curva desde 0 hasta 0.0809: 0.0854
# Área bajo la curva desde 0 hasta 0.0811: 0.0876
# Área bajo la curva desde 0 hasta 0.0813: 0.0899
# Área bajo la curva desde 0 hasta 0.0815: 0.0923
# Área bajo la curva desde 0 hasta 0.0817: 0.0947
# Área bajo la curva desde 0 hasta 0.0819: 0.0971
# Área bajo la curva desde 0 hasta 0.0821: 0.0996
# Área bajo la curva desde 0 hasta 0.0823: 0.1021
# Área bajo la curva desde 0 hasta 0.0825: 0.1047
# Área bajo la curva desde 0 hasta 0.0827: 0.1074
# Área bajo la curva desde 0 hasta 0.0829: 0.1100
# Área bajo la curva desde 0 hasta 0.0831: 0.1127
# Área bajo la curva desde 0 hasta 0.0833: 0.1155
# Área bajo la curva desde 0 hasta 0.0835: 0.1183
# Área bajo la curva desde 0 hasta 0.0837: 0.1212
# Área bajo la curva desde 0 hasta 0.0839: 0.1241
# Área bajo la curva desde 0 hasta 0.0841: 0.1271
# Área bajo la curva desde 0 hasta 0.0843: 0.1301
# Área bajo la curva desde 0 hasta 0.0845: 0.1331
# Área bajo la curva desde 0 hasta 0.0847: 0.1363
# Área bajo la curva desde 0 hasta 0.0849: 0.1394
# Área bajo la curva desde 0 hasta 0.0851: 0.1426
# Área bajo la curva desde 0 hasta 0.0853: 0.1459
# Área bajo la curva desde 0 hasta 0.0855: 0.1492
# Área bajo la curva desde 0 hasta 0.0857: 0.1525
# Área bajo la curva desde 0 hasta 0.0859: 0.1560
# Área bajo la curva desde 0 hasta 0.0861: 0.1594
# Área bajo la curva desde 0 hasta 0.0863: 0.1629
# Área bajo la curva desde 0 hasta 0.0865: 0.1665
# Área bajo la curva desde 0 hasta 0.0867: 0.1701
# Área bajo la curva desde 0 hasta 0.0869: 0.1737
# Área bajo la curva desde 0 hasta 0.0871: 0.1774
# Área bajo la curva desde 0 hasta 0.0873: 0.1812
# Área bajo la curva desde 0 hasta 0.0875: 0.1850
# Área bajo la curva desde 0 hasta 0.0877: 0.1888
# Área bajo la curva desde 0 hasta 0.0879: 0.1928
# Área bajo la curva desde 0 hasta 0.0881: 0.1967
# Área bajo la curva desde 0 hasta 0.0883: 0.2007
# Área bajo la curva desde 0 hasta 0.0885: 0.2048
# Área bajo la curva desde 0 hasta 0.0887: 0.2088
# Área bajo la curva desde 0 hasta 0.0889: 0.2130
# Área bajo la curva desde 0 hasta 0.0891: 0.2172
# Área bajo la curva desde 0 hasta 0.0893: 0.2214
# Área bajo la curva desde 0 hasta 0.0895: 0.2257
# Área bajo la curva desde 0 hasta 0.0897: 0.2300
# Área bajo la curva desde 0 hasta 0.0899: 0.2344
# Área bajo la curva desde 0 hasta 0.0901: 0.2388
# Área bajo la curva desde 0 hasta 0.0903: 0.2433
# Área bajo la curva desde 0 hasta 0.0905: 0.2478
# Área bajo la curva desde 0 hasta 0.0907: 0.2524
# Área bajo la curva desde 0 hasta 0.0909: 0.2570
# Área bajo la curva desde 0 hasta 0.0911: 0.2616
# Área bajo la curva desde 0 hasta 0.0913: 0.2663
# Área bajo la curva desde 0 hasta 0.0915: 0.2711
# Área bajo la curva desde 0 hasta 0.0917: 0.2758
# Área bajo la curva desde 0 hasta 0.0919: 0.2806
# Área bajo la curva desde 0 hasta 0.0921: 0.2855
# Área bajo la curva desde 0 hasta 0.0923: 0.2904
# Área bajo la curva desde 0 hasta 0.0925: 0.2953
# Área bajo la curva desde 0 hasta 0.0927: 0.3003
# Área bajo la curva desde 0 hasta 0.0929: 0.3053
# Área bajo la curva desde 0 hasta 0.0931: 0.3103
# Área bajo la curva desde 0 hasta 0.0933: 0.3154
# Área bajo la curva desde 0 hasta 0.0935: 0.3205
# Área bajo la curva desde 0 hasta 0.0937: 0.3257
# Área bajo la curva desde 0 hasta 0.0939: 0.3309
# Área bajo la curva desde 0 hasta 0.0941: 0.3361
# Área bajo la curva desde 0 hasta 0.0943: 0.3413
# Área bajo la curva desde 0 hasta 0.0945: 0.3466
# Área bajo la curva desde 0 hasta 0.0947: 0.3519
# Área bajo la curva desde 0 hasta 0.0949: 0.3573
# Área bajo la curva desde 0 hasta 0.0951: 0.3626
# Área bajo la curva desde 0 hasta 0.0953: 0.3680
# Área bajo la curva desde 0 hasta 0.0955: 0.3734
# Área bajo la curva desde 0 hasta 0.0957: 0.3789
# Área bajo la curva desde 0 hasta 0.0959: 0.3844
# Área bajo la curva desde 0 hasta 0.0961: 0.3899
# Área bajo la curva desde 0 hasta 0.0963: 0.3954
# Área bajo la curva desde 0 hasta 0.0965: 0.4009
# Área bajo la curva desde 0 hasta 0.0967: 0.4065
# Área bajo la curva desde 0 hasta 0.0969: 0.4120
# Área bajo la curva desde 0 hasta 0.0971: 0.4176
# Área bajo la curva desde 0 hasta 0.0973: 0.4232
# Área bajo la curva desde 0 hasta 0.0975: 0.4289
# Área bajo la curva desde 0 hasta 0.0977: 0.4345
# Área bajo la curva desde 0 hasta 0.0979: 0.4401
# Área bajo la curva desde 0 hasta 0.0981: 0.4458
# Área bajo la curva desde 0 hasta 0.0983: 0.4515
# Área bajo la curva desde 0 hasta 0.0985: 0.4572
# Área bajo la curva desde 0 hasta 0.0987: 0.4629
# Área bajo la curva desde 0 hasta 0.0989: 0.4686
# Área bajo la curva desde 0 hasta 0.0991: 0.4743
# Área bajo la curva desde 0 hasta 0.0993: 0.4800
# Área bajo la curva desde 0 hasta 0.0995: 0.4857
# Área bajo la curva desde 0 hasta 0.0997: 0.4914
# Área bajo la curva desde 0 hasta 0.0999: 0.4971
# Área bajo la curva desde 0 hasta 0.1001: 0.5029
# Área bajo la curva desde 0 hasta 0.1003: 0.5086
# Área bajo la curva desde 0 hasta 0.1005: 0.5143
# Área bajo la curva desde 0 hasta 0.1007: 0.5200
# Área bajo la curva desde 0 hasta 0.1009: 0.5257
# Área bajo la curva desde 0 hasta 0.1011: 0.5314
# Área bajo la curva desde 0 hasta 0.1013: 0.5371
# Área bajo la curva desde 0 hasta 0.1015: 0.5428
# Área bajo la curva desde 0 hasta 0.1017: 0.5485
# Área bajo la curva desde 0 hasta 0.1019: 0.5542
# Área bajo la curva desde 0 hasta 0.1021: 0.5599
# Área bajo la curva desde 0 hasta 0.1023: 0.5655
# Área bajo la curva desde 0 hasta 0.1025: 0.5711
# Área bajo la curva desde 0 hasta 0.1027: 0.5768
# Área bajo la curva desde 0 hasta 0.1029: 0.5824
# Área bajo la curva desde 0 hasta 0.1031: 0.5880
# Área bajo la curva desde 0 hasta 0.1033: 0.5935
# Área bajo la curva desde 0 hasta 0.1035: 0.5991
# Área bajo la curva desde 0 hasta 0.1037: 0.6046
# Área bajo la curva desde 0 hasta 0.1039: 0.6101
# Área bajo la curva desde 0 hasta 0.1041: 0.6156
# Área bajo la curva desde 0 hasta 0.1043: 0.6211
# Área bajo la curva desde 0 hasta 0.1045: 0.6266
# Área bajo la curva desde 0 hasta 0.1047: 0.6320
# Área bajo la curva desde 0 hasta 0.1049: 0.6374
# Área bajo la curva desde 0 hasta 0.1051: 0.6427
# Área bajo la curva desde 0 hasta 0.1053: 0.6481
# Área bajo la curva desde 0 hasta 0.1055: 0.6534
# Área bajo la curva desde 0 hasta 0.1057: 0.6587
# Área bajo la curva desde 0 hasta 0.1059: 0.6639
# Área bajo la curva desde 0 hasta 0.1061: 0.6691
# Área bajo la curva desde 0 hasta 0.1063: 0.6743
# Área bajo la curva desde 0 hasta 0.1065: 0.6795
# Área bajo la curva desde 0 hasta 0.1067: 0.6846
# Área bajo la curva desde 0 hasta 0.1069: 0.6897
# Área bajo la curva desde 0 hasta 0.1071: 0.6947
# Área bajo la curva desde 0 hasta 0.1073: 0.6997
# Área bajo la curva desde 0 hasta 0.1075: 0.7047
# Área bajo la curva desde 0 hasta 0.1077: 0.7096
# Área bajo la curva desde 0 hasta 0.1079: 0.7145
# Área bajo la curva desde 0 hasta 0.1081: 0.7194
# Área bajo la curva desde 0 hasta 0.1083: 0.7242
# Área bajo la curva desde 0 hasta 0.1085: 0.7289
# Área bajo la curva desde 0 hasta 0.1087: 0.7337
# Área bajo la curva desde 0 hasta 0.1089: 0.7384
# Área bajo la curva desde 0 hasta 0.1091: 0.7430
# Área bajo la curva desde 0 hasta 0.1093: 0.7476
# Área bajo la curva desde 0 hasta 0.1095: 0.7522
# Área bajo la curva desde 0 hasta 0.1097: 0.7567
# Área bajo la curva desde 0 hasta 0.1099: 0.7612
# Área bajo la curva desde 0 hasta 0.1101: 0.7656
# Área bajo la curva desde 0 hasta 0.1103: 0.7700
# Área bajo la curva desde 0 hasta 0.1105: 0.7743
# Área bajo la curva desde 0 hasta 0.1107: 0.7786
# Área bajo la curva desde 0 hasta 0.1109: 0.7828
# Área bajo la curva desde 0 hasta 0.1111: 0.7870
# Área bajo la curva desde 0 hasta 0.1113: 0.7912
# Área bajo la curva desde 0 hasta 0.1115: 0.7952
# Área bajo la curva desde 0 hasta 0.1117: 0.7993
# Área bajo la curva desde 0 hasta 0.1119: 0.8033
# Área bajo la curva desde 0 hasta 0.1121: 0.8072
# Área bajo la curva desde 0 hasta 0.1123: 0.8112
# Área bajo la curva desde 0 hasta 0.1125: 0.8150
# Área bajo la curva desde 0 hasta 0.1127: 0.8188
# Área bajo la curva desde 0 hasta 0.1129: 0.8226
# Área bajo la curva desde 0 hasta 0.1131: 0.8263
# Área bajo la curva desde 0 hasta 0.1133: 0.8299
# Área bajo la curva desde 0 hasta 0.1135: 0.8335
# Área bajo la curva desde 0 hasta 0.1137: 0.8371
# Área bajo la curva desde 0 hasta 0.1139: 0.8406
# Área bajo la curva desde 0 hasta 0.1141: 0.8440
# Área bajo la curva desde 0 hasta 0.1143: 0.8475
# Área bajo la curva desde 0 hasta 0.1145: 0.8508
# Área bajo la curva desde 0 hasta 0.1147: 0.8541
# Área bajo la curva desde 0 hasta 0.1149: 0.8574
# Área bajo la curva desde 0 hasta 0.1151: 0.8606
# Área bajo la curva desde 0 hasta 0.1153: 0.8637
# Área bajo la curva desde 0 hasta 0.1155: 0.8669
# Área bajo la curva desde 0 hasta 0.1157: 0.8699
# Área bajo la curva desde 0 hasta 0.1159: 0.8729
# Área bajo la curva desde 0 hasta 0.1161: 0.8759
# Área bajo la curva desde 0 hasta 0.1163: 0.8788
# Área bajo la curva desde 0 hasta 0.1165: 0.8817
# Área bajo la curva desde 0 hasta 0.1167: 0.8845
# Área bajo la curva desde 0 hasta 0.1169: 0.8873
# Área bajo la curva desde 0 hasta 0.1171: 0.8900
# Área bajo la curva desde 0 hasta 0.1173: 0.8926
# Área bajo la curva desde 0 hasta 0.1175: 0.8953
# Área bajo la curva desde 0 hasta 0.1177: 0.8979
# Área bajo la curva desde 0 hasta 0.1179: 0.9004
# Área bajo la curva desde 0 hasta 0.1181: 0.9029
# Área bajo la curva desde 0 hasta 0.1183: 0.9053
# Área bajo la curva desde 0 hasta 0.1185: 0.9077
# Área bajo la curva desde 0 hasta 0.1187: 0.9101
# Área bajo la curva desde 0 hasta 0.1189: 0.9124
# Área bajo la curva desde 0 hasta 0.1191: 0.9146
# Área bajo la curva desde 0 hasta 0.1193: 0.9168
# Área bajo la curva desde 0 hasta 0.1195: 0.9190
# Área bajo la curva desde 0 hasta 0.1197: 0.9212
# Área bajo la curva desde 0 hasta 0.1199: 0.9232
# Área bajo la curva desde 0 hasta 0.1201: 0.9253
# Área bajo la curva desde 0 hasta 0.1203: 0.9273
# Área bajo la curva desde 0 hasta 0.1205: 0.9293
# Área bajo la curva desde 0 hasta 0.1207: 0.9312
# Área bajo la curva desde 0 hasta 0.1209: 0.9331
# Área bajo la curva desde 0 hasta 0.1211: 0.9349
# Área bajo la curva desde 0 hasta 0.1213: 0.9367
# Área bajo la curva desde 0 hasta 0.1215: 0.9385
# Área bajo la curva desde 0 hasta 0.1217: 0.9402
# Área bajo la curva desde 0 hasta 0.1219: 0.9419
# Área bajo la curva desde 0 hasta 0.1221: 0.9435
# Área bajo la curva desde 0 hasta 0.1223: 0.9451
# Área bajo la curva desde 0 hasta 0.1225: 0.9467
# Área bajo la curva desde 0 hasta 0.1227: 0.9482
# Área bajo la curva desde 0 hasta 0.1229: 0.9497

# %%
print(f"El valor crítico para un nivel de confianza del {condicion*100}% es: {x_critico}")
# Out:
# El valor crítico para un nivel de confianza del 95.0% es: 0.12292292292292292

# %% [markdown]
# Ahora calculemos la estimacion puntual de $p$ con los datos muestrales:

# %%
p_estimacion = p_muestral
print(f"El valor de p estimado a partir de la muestra es: {p_estimacion:.4f}")
# Out:
# El valor de p estimado a partir de la muestra es: 0.1104

# %% [markdown]
# **Conclusión** No se puede rechazar $H_0$ con los datos muestrales obtenidos por lo tanto, se rechaza que $p > 0.1$

# %%
(-p_Hnula + p_muestral)/np.sqrt(sigma2_p_hat)
# Out:
# np.float64(0.7443873683187759)

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_values_p_hat, normal_values_p_hat , 'b-', linewidth=2)

# Llenar entre dos valores de x
mask1 = (x_values_p_hat <= x_critico)

plt.fill_between(x_values_p_hat[mask1], np.array(normal_values_p_hat)[mask1], alpha=0.5, color='red', label='Área entre x=40 y x=60')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
